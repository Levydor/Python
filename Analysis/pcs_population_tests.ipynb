# %%
import json
import pandas as pd
import re
import operator 
import numpy as np
from IPython.display import display
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 50)
pd.set_option('display.width', 1000)
sol, a, max_val = [], [], 0

def atoi(text):
    return int(text) if text.isdigit() else text

def natural_keys(text):
    return [ atoi(c) for c in re.split('(\d+)', text) ]

f1 = "W:\\Work\\Assense\\ML\\DataFrames\\pcs_features_10_02_19.json"
f2 = "W:\\Work\\Assense\\ML\\DataFrames\\PZL_300p_Test_24_02_19.json" # pzl.r_tCompletion
# path = "W:\\Work\\Assense\\ML\\DataFrames\\IDF_pcs_shp_ang_pzl_03_02_19.csv"
with open(f1, 'r') as f:
    data = json.load(f)
df1 = pd.DataFrame.from_dict(data)

#    if re.search('r_fSwapsVsMinSwaps\.|r_fSwapsVsMinSwaps\_',col):

#number of Object gazed before solution
for col in list(df1.columns):
    if re.search('r_t1stButtonClick\.',col):
        sol.append(col)
df = df1[sol]
print(df.shape)
new_df = df.dropna(how = 'all')  # dropping full nan row
new_cols = [col[:] for col in new_df.columns]
new_df.columns = new_cols

for col in sorted(df.columns):
    a.append(col)

a.sort(key=natural_keys)
new_df = new_df[a]
new_df


# f_sum = new_df['r_atBtwClicksDuringHandle.0']
# d_sum = f_sum.to_dict()
# user = max(d_sum.items(), key= lambda x: x[1])[0]
# val = max(d_sum.items(), key= lambda x: x[1])[1]
# print(user, val)
# df


#74002196 5.6796613329 min
#42126941 28.7603068 max
# Out:
# (169, 88)
# ...

# %%
for col in list(df1.columns):
    if re.search('r_tCompletion\.|r_tCompletion\_',col):
        sol.append(col)
df = df1[sol]
print(df.shape)
df.head()

# %%
import json
import pandas as pd
import re
import operator 
import numpy as np
from IPython.display import display
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.width', 1000)
sol, a, max_val = [], [], 0

def atoi(text):
    return int(text) if text.isdigit() else text

def natural_keys(text):
    return [ atoi(c) for c in re.split('(\d+)', text) ]

f1 = "W:\\Work\\Assense\\ML\\DataFrames\\IDF_ATAL_pcs_21_02_19.json"

with open(f1, 'r') as f:
    data = json.load(f)
df1 = pd.DataFrame.from_dict(data)


#number of Object gazed before solution
for col in list(df1.columns):
    if re.search('r_nLabelsSwitched',col):
        sol.append(col)
df = df1[sol]
print(df.shape)
new_df = df.dropna(how = 'all')  # dropping full nan row
new_cols = [col[:] for col in new_df.columns]
new_df.columns = new_cols

for col in sorted(df.columns):
    a.append(col)

a.sort(key=natural_keys)
new_df = new_df[a]
new_df
new_df.iloc[[5]]

f_sum = new_df['pcs.r_nLabelsSwitched_ass']
d_sum = f_sum.to_dict()
user = max(d_sum.items(), key= lambda x: x[1])[0]
val = max(d_sum.items(), key= lambda x: x[1])[1]
print(user, val)
new_df.iloc[[5]]


#74002196 5.6796613329 min
#42126941 28.7603068 max
# Out:
# (66, 0)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\NewProg\Anaconda\lib\site-packages\pandas\core\indexing.py in _get_list_axis(self, key, axis)
#    2069         try:
# -> 2070             return self.obj._take(key, axis=axis)
#    2071         except IndexError:
#
# C:\NewProg\Anaconda\lib\site-packages\pandas\core\generic.py in _take(self, indices, axis, is_copy)
#    2788                                    axis=self._get_block_manager_axis(axis),
# -> 2789                                    verify=True)
#    2790         result = self._constructor(new_data).__finalize__(self)
#
# C:\NewProg\Anaconda\lib\site-packages\pandas\core\internals.py in take(self, indexer, axis, verify, convert)
#    4529         if convert:
# -> 4530             indexer = maybe_convert_indices(indexer, n)
#    4531
#
# ...

# %%
import json
import pandas as pd
import re
import operator 
import matplotlib.pyplot as plt
sol, max_val = [], 0

pd.options.display.max_columns = None
pd.options.display.max_rows = None
f2 = "W:\\Work\\Assense\\ML\\DataFrames\\pcs_features_10_02_19.json"
with open(f2, 'r') as f:
    data = json.load(f)
df1 = pd.DataFrame.from_dict(data)
for col in list(df1.columns):
    if re.search('r_tTotal_sum',col):
        sol.append(col)

df = df1['pcs.r_tTotal_sum']
df.index.name = 'ind'
 
d1 = df.to_dict()
user = min(d1.items(), key= lambda x: x[1])[0]
val = min(d1.items(), key= lambda x: x[1])[1]
print(user,val)


# t_sum = [tuple(x, y) for x, y in df.items()]

# %%
# sort columns in alphabetical order

a = [];
for col in sorted(df.columns):
    a.append(col)
    
import re

def atoi(text):
    return int(text) if text.isdigit() else text

def natural_keys(text):
    return [ atoi(c) for c in re.split('(\d+)', text) ]

a.sort(key=natural_keys)

#df = df[a]

# %%
import json
import pandas as pd
import re
import operator 
import numpy as np
from IPython.display import display
import matplotlib.pyplot as plt
sol, max_val = [], 0

pd.options.display.max_columns = None
pd.options.display.max_rows = None
f2 = "W:\\Work\\Assense\\ML\\DataFrames\\pcs_features_10_02_19.json"
with open(f2, 'r') as f:
    data = json.load(f)
df1 = pd.DataFrame.from_dict(data)
for col in list(df1.columns):
    if re.search('pcs.r_bSpeedDecreaseAfterLostPackage',col):
        sol.append(col)
        
df = df1[sol] 
df.head()
# a.sort(key=natural_keys)
# df = df[a]
# df.head()

# df = df1['pcs.r_bPassTimeLimit_sum']
# df 

# d2 = df.to_dict()
# user = min(d2.items(), key= lambda x: x[1])[0]
# val = min(d2.items(), key= lambda x: x[1])[1]
# print(user,val)

# %%
import json
import pandas as pd
import re
import operator 
import numpy as np
from IPython.display import display
import matplotlib.pyplot as plt
sol, max_val = [], 0

pd.options.display.max_columns = None
pd.options.display.max_rows = None
f2 = "W:\\Work\\Assense\\ML\\DataFrames\\PCS_Test_case_a_features.json"
with open(f2, 'r') as f:
    data = json.load(f)
df1 = pd.DataFrame.from_dict(data)
for col in list(df1.columns):
    if re.search('pcs.r_sCorrectness',col):
        sol.append(col)
df = df1[sol] 
df
a.sort(key=natural_keys)
df = df[a]
df

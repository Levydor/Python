# %%
import json
import pandas as pd
import re
import matplotlib.pyplot as plt

sol = []
file = "W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_cognitive_ability_total_score_w_shp_220119\\deloitte_cognitive_ability_total_score_w_shp_220119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('deloitte')
for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)

for col in list(df.columns):
    if re.search('grade_no_round',col):
        sol.append(col)
df[sol].hist()
plt.title(col,fontsize=9)
# Out:
# deloitte
# yessssssss
# Text(0.5,1,'cog_cognitive_ability_total_score_w_shp_220119.grade_no_round')

# %%
file = "W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_cognitive_ability_total_score_w_shp_220119\\jsol_cognitive_ability_total_score_w_shp_220119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('Jsol')
for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# Jsol

# %%
file = "W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_cognitive_ability_total_score_w_shp_220119\\sherrot_cognitive_ability_total_score_w_shp_220119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('Sherrot')
for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# Sherrot

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_cognitive_ability_total_score_w_shp_220119\\wechs_cognitive_ability_total_score_w_shp_220119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('cognitive_ability_total_score_w_shp_220119')
print('Wechs')
for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# cognitive_ability_total_score_w_shp_220119
# Wechs

# %%
file = "W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_cognitive_ability_total_score_w_shp_220119\\full_cognitive_ability_total_score_w_shp_220119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('full population')
for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# full population

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_performance_IQ_w_shp_220119\\deloitte_performance_IQ_w_shp_220119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('performance_IQ_w_shp_220119')
print('deloitte_performance_IQ_w_shp_220119')
for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# performance_IQ_w_shp_220119
# deloitte_performance_IQ_w_shp_220119

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_performance_IQ_w_shp_220119\\jsol_performance_IQ_w_shp_220119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('jsol_performance_IQ_w_shp_220119')

for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# jsol_performance_IQ_w_shp_220119

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_performance_IQ_w_shp_220119\\sheroot_performance_IQ_w_shp_220119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('sheroot_performance_IQ_w_shp_220119')

for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# sheroot_performance_IQ_w_shp_220119

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_performance_IQ_w_shp_220119\\wechs_performance_IQ_w_shp_220119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('wechs_performance_IQ_w_shp_220119')

for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# wechs_performance_IQ_w_shp_220119

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_performance_IQ_w_shp_220119\\full_performance_IQ_w_shp_220119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('full_performance_IQ_w_shp_220119')

for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# full_performance_IQ_w_shp_220119

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_prossecing_speed_lin_noACC_280119\\deloitte_prossecing_speed_lin_noACC_280119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('deloitte_prossecing_speed_lin_noACC_280119')

for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# deloitte_prossecing_speed_lin_noACC_280119

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_prossecing_speed_lin_noACC_280119\\jsol_prossecing_speed_lin_noACC_280119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('jsol_prossecing_speed_lin_noACC_280119')

for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# jsol_prossecing_speed_lin_noACC_280119

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_prossecing_speed_lin_noACC_280119\\sheroot_prossecing_speed_lin_noACC_280119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('sheroot_prossecing_speed_lin_noACC_280119')

for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# sheroot_prossecing_speed_lin_noACC_280119

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_prossecing_speed_lin_noACC_280119\\wechs_prossecing_speed_lin_noACC_280119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('wechs_prossecing_speed_lin_noACC_280119')

for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# wechs_prossecing_speed_lin_noACC_280119

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_prossecing_speed_lin_noACC_280119\\full_prossecing_speed_lin_noACC_280119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('full_prossecing_speed_lin_noACC_280119')

for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# full_prossecing_speed_lin_noACC_280119

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_prossecing_speed_noAcc_280119\\deloitte_prossecing_speed_noAcc_280119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('deloitte_prossecing_speed_noAcc_280119')

for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# deloitte_prossecing_speed_noAcc_280119

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_prossecing_speed_noAcc_280119\\jsol_prossecing_speed_noAcc_280119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('jsol_prossecing_speed_noAcc_280119')

for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# jsol_prossecing_speed_noAcc_280119

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_prossecing_speed_noAcc_280119\\sheroot_prossecing_speed_noAcc_280119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('sheroot_prossecing_speed_noAcc_280119')

for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# sheroot_prossecing_speed_noAcc_280119

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_prossecing_speed_noAcc_280119\\wechs_pzl_ana_shp_14_1_19.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('wechs_pzl_ana_shp_14_1_19')

for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# wechs_pzl_ana_shp_14_1_19

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_prossecing_speed_noAcc_280119\\full_prossecing_speed_noAcc_280119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('full_prossecing_speed_noAcc_280119')

for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# full_prossecing_speed_noAcc_280119

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_prossecing_speed_w_shp_220119\\deloitte_prossecing_speed_w_shp_220119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print("prossecing_speed_w_shp_220119")
print('deloitte_prossecing_speed_w_shp_220119')

for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# prossecing_speed_w_shp_220119
# deloitte_prossecing_speed_w_shp_220119

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_prossecing_speed_w_shp_220119\\sheroot_prossecing_speed_w_shp_220119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('sheroot_prossecing_speed_w_shp_220119')

for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# sheroot_prossecing_speed_w_shp_220119

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_prossecing_speed_w_shp_220119\\wechs_prossecing_speed_w_shp_220119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('wechs_prossecing_speed_w_shp_220119')

for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# wechs_prossecing_speed_w_shp_220119

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_prossecing_speed_w_shp_220119\\Full_prossecing_speed_w_shp_220119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('Full_prossecing_speed_w_shp_220119')

for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# Full_prossecing_speed_w_shp_220119

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_prossecing_speed_wAcc_280119\\deloitte_prossecing_speed_wAcc_280119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('cog_prossecing_speed_wAcc_280119')
print('deloitte_prossecing_speed_wAcc_280119')

for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# deloitte_prossecing_speed_w_shp_220119

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_prossecing_speed_wAcc_280119\\jsol_prossecing_speed_wAcc_280119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('jsol_prossecing_speed_wAcc_280119')

for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# jsol_prossecing_speed_wAcc_280119

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_prossecing_speed_wAcc_280119\\sheroot_prossecing_speed_wAcc_280119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('sheroot_prossecing_speed_wAcc_280119')

for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# sheroot_prossecing_speed_wAcc_280119

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_prossecing_speed_wAcc_280119\\wechs_prossecing_speed_wAcc_280119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('wechs_prossecing_speed_wAcc_280119')

for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# wechs_prossecing_speed_wAcc_280119

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_prossecing_speed_wAcc_280119\\full_prossecing_speed_wAcc_280119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('full_prossecing_speed_wAcc_280119')

for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# full_prossecing_speed_wAcc_280119

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_spatial_reasoning_w_shp_220119\\deloitte_spatial_reasoning_w_shp_220119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('cog_spatial_reasoning_w_shp_220119')
print('deloitte_spatial_reasoning_w_shp_220119')

for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# cog_spatial_reasoning_w_shp_220119
# deloitte_spatial_reasoning_w_shp_220119

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_spatial_reasoning_w_shp_220119\\jsol_spatial_reasoning_w_shp_220119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('jsol_spatial_reasoning_w_shp_220119')

for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# jsol_spatial_reasoning_w_shp_220119

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_spatial_reasoning_w_shp_220119\\sheroot_spatial_reasoning_w_shp_220119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('sheroot_spatial_reasoning_w_shp_220119')

for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# sheroot_spatial_reasoning_w_shp_220119

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_spatial_reasoning_w_shp_220119\\wechs_spatial_reasoning_w_shp_220119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('wechs_spatial_reasoning_w_shp_220119')

for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# wechs_spatial_reasoning_w_shp_220119

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_spatial_reasoning_w_shp_220119\\full_spatial_reasoning_w_shp_220119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('full_spatial_reasoning_w_shp_220119')

for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# full_spatial_reasoning_w_shp_220119

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_verbal_reasoning_150119\\deloitte_verbal_reasoning_150119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('cog_verbal_reasoning_150119')
print('deloitte_verbal_reasoning_150119')
for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# cog_verbal_reasoning_150119
# deloitte_verbal_reasoning_150119

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_verbal_reasoning_150119\\jsol_verbal_reasoning_150119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('jsol_verbal_reasoning_150119')
for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# jsol_verbal_reasoning_150119

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_verbal_reasoning_150119\\sheroot_verbal_reasoning_150119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('sheroot_verbal_reasoning_150119')
for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# sheroot_verbal_reasoning_150119

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_verbal_reasoning_150119\\wechs_verbal_reasoning_150119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('wechs_verbal_reasoning_150119')
for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# wechs_verbal_reasoning_150119

# %%
file="W:\\Work\\Assense\\ML\\Predictions\\populations_comparisons\\cog_verbal_reasoning_150119\\full_verbal_reasoning_150119.json"
with open(file, 'r') as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data)
df
plt.figure(figsize=(20,10))
print('full_verbal_reasoning_150119')
for i,col in enumerate(df.columns):
    plt.subplot(3,4,i+1)
    df[col].hist()
    plt.title(col,fontsize=9)
# Out:
# full_verbal_reasoning_150119

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import time

from sklearn import linear_model
from sklearn import metrics
from sklearn.model_selection import train_test_split, cross_val_score, cross_validate, RepeatedKFold
from math import sqrt
from scipy import stats
from sklearn import preprocessing
from sklearn import ensemble
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, learning_curve
# import ifsg
import json
import re
import glob, os #I ADDED
from sklearn.svm import SVR, LinearSVR #I ADDED
from sklearn.tree import DecisionTreeRegressor #I ADDED

pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 500)
#pd.set_option('display.width', 1000)
# Out:
# <style>.container { width:100% !important; }</style>
# C:\NewProg\Anaconda\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
file = "W:\\Work\\Assense\\ML\\Production_structure\\Populations\\pop_shortVR_sheroot_j_e_idf_nofilter180219.json"
with open(file) as train_file:
    dict_train = json.load(train_file)
df = pd.DataFrame.from_dict(dict_train)
print(df.shape)
# df
# Out:
# (131, 8)

# %%
file = "C:\\Users\\VORTEX\\Desktop\\missmatches\\df_shortVR_sheroot_j_e_idf_nofilter180219.json"
r = ['pcs.r_hasPackageWeighted_sum', 'pcs.r_hasCheckedPrice_sum', 'pcs.r_HasPackageXrayed_sum', 'pcs.r_fAccuracy_ass']
sol = []
with open(file) as train_file:
    dict_train = json.load(train_file)
df = pd.DataFrame.from_dict(dict_train)
print(df.shape)
df
for col in list(df.columns):
    if col in r:
        sol.append(col)
df1= df[sol]
df1


# f_sum = df1['pcs.r_hasPackageWeighted_sum']
# d_sum = f_sum.to_dict()
# user = max(d_sum.items(), key= lambda x: x[1])[0]
# val = max(d_sum.items(), key= lambda x: x[1])[1]
# print(user, val)
# df1

# pcs.r_fAccuracy_ass
# max -E1234532 0.593446277
# min  H3 -1.34533468

# pcs.r_HasPackageXrayed_sum
# max 17159510 58.0
# min 70487856 0.0

# pcs.r_hasCheckedPrice_sum
# max 87386139 52.0
# min 70487856 0.0

# pcs.r_hasPackageWeighted_sum
# max 27911951 64.0
# min 70487856 0.0
# Out:
# (162, 4952)
# 27911951 64.0
#           pcs.r_fAccuracy_ass  pcs.r_HasPackageXrayed_sum  \
# 10764763             0.447189                        56.0
# 13013254             0.326552                        57.0
# 13811061            -0.193318                        44.0
# 17159510            -0.303200                        58.0
# 17405816             0.132335                        53.0
# 17706792             0.050848                        55.0
# 21292822            -0.285144                        40.0
# 23885495             0.100725                        55.0
# 24256398             0.081271                        57.0
# 27754368             0.453642                        58.0
# 27911951             0.009813                        53.0
# 29777881             0.161274                        44.0
# 32204797             0.178309                        55.0
# 33817374             0.510036                        58.0
# 36896774             0.114357                        53.0
# ...
